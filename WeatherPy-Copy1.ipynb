# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

units = "imperial"
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_df = pd.DataFrame({
    "City Name":[],
    "Country":[],
    "Latitude":[],
    "Longitude":[],
    "Date":[],
    "Temperature":[], 
    "Humidity":[],
    "Wind Speed":[],
    "Clouds":[]
})

print("""
                             Beginning Data Retrieval
--------------------------------------------------------------------------------
""")
count = 1

for i in range(len(cities)):
    try:
        query_url = f"{base_url}appid={api_keys.api_key}&q={cities[i]}&units={units}"
        print(f"Processing Record {count} of Set 1 | {cities[i]}")
        
        response = requests.get(query_url)
        weather_json = response.json()
        
        cty_cloud = weather_json["clouds"]["all"]
        cty_cntry = weather_json["sys"]["country"]
        cty_date = time.strftime('%Y-%m-%d', time.localtime(weather_json["dt"]))
        cty_humid = weather_json["main"]["humidity"]
        cty_lat = weather_json["coord"]["lat"]
        cty_long = weather_json["coord"]["lat"]
        cty_mx_tmp = weather_json["main"]["temp_max"]
        cty_wndspd = weather_json["wind"]["speed"]
        
        weather_df = weather_df.append({
            "City Name":cities[i],
            "Country":cty_cntry,
            "Latitude":cty_lat,
            "Longitude":cty_long,
            "Date":cty_date,
            "Temperature":cty_mx_tmp, 
            "Humidity":cty_humid,
            "Wind Speed":cty_wndspd,
            "Clouds":cty_cloud
        }, ignore_index=True)
        count+=1
    except:
        print("Insufficient data. Skipping..")
print("""
--------------------------------------------------------------------------------
                                Data Retrieval Complete
--------------------------------------------------------------------------------
""")
# Out:
#                              Beginning Data Retrieval
# --------------------------------------------------------------------------------
#
# Processing Record 1 of Set 1 | taolanaro
# Insufficient data. Skipping..
# Processing Record 1 of Set 1 | rawannawi
# Insufficient data. Skipping..
# Processing Record 1 of Set 1 | wuchang
# Processing Record 2 of Set 1 | pangnirtung
# Processing Record 3 of Set 1 | illoqqortoormiut
# Insufficient data. Skipping..
# Processing Record 3 of Set 1 | were ilu
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | guerrero negro
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | hervey bay
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | marechal candido rondon
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | seymchan
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | kununurra
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | amderma
# Insufficient data. Skipping..
# Processing Record 25 of Set 1 | alice springs
# Processing Record 26 of Set 1 | husavik
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | vila velha
# Processing Record 29 of Set 1 | novosysoyevka
# Processing Record 30 of Set 1 | krasnorechenskiy
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | talnakh
# Processing Record 158 of Set 1 | raudeberg
# Processing Record 159 of Set 1 | kulhudhuffushi
# Processing Record 160 of Set 1 | laguna
# Processing Record 161 of Set 1 | caravelas
# Processing Record 162 of Set 1 | faanui
# Processing Record 163 of Set 1 | flinders
# Processing Record 164 of Set 1 | develi
# Processing Record 165 of Set 1 | coihaique
# Processing Record 166 of Set 1 | chokurdakh
# Processing Record 167 of Set 1 | mingyue
# Processing Record 168 of Set 1 | cidreira
# Processing Record 169 of Set 1 | lompoc
# Processing Record 170 of Set 1 | severo-kurilsk
# Processing Record 171 of Set 1 | arti
# Processing Record 172 of Set 1 | ryotsu
# Processing Record 173 of Set 1 | kadaura
# Processing Record 174 of Set 1 | norman wells
# Processing Record 175 of Set 1 | hopelchen
# Processing Record 176 of Set 1 | nikolskoye
# Processing Record 177 of Set 1 | cayenne
# Processing Record 178 of Set 1 | ahipara
# Processing Record 179 of Set 1 | longlac
# Insufficient data. Skipping..
# Processing Record 179 of Set 1 | atambua
# Processing Record 180 of Set 1 | onega
# Processing Record 181 of Set 1 | arman
# Processing Record 182 of Set 1 | am timan
# Processing Record 183 of Set 1 | boa vista
# Processing Record 184 of Set 1 | sobolevo
# Processing Record 185 of Set 1 | gull lake
# Processing Record 186 of Set 1 | tawkar
# Insufficient data. Skipping..
# Processing Record 186 of Set 1 | havoysund
# Processing Record 187 of Set 1 | huarmey
# Processing Record 188 of Set 1 | attawapiskat
# Insufficient data. Skipping..
# Processing Record 188 of Set 1 | mullaitivu
# Insufficient data. Skipping..
# Processing Record 188 of Set 1 | falun
# Processing Record 189 of Set 1 | ulladulla
# Processing Record 190 of Set 1 | gigmoto
# Processing Record 191 of Set 1 | chisec
# Processing Record 192 of Set 1 | san carlos de bariloche
# Processing Record 193 of Set 1 | scottsburgh
# Insufficient data. Skipping..
# Processing Record 193 of Set 1 | luebo
# Processing Record 194 of Set 1 | nome
# Processing Record 195 of Set 1 | zemen
# Processing Record 196 of Set 1 | manta
# Processing Record 197 of Set 1 | la paz
# Processing Record 198 of Set 1 | bagan
# Processing Record 199 of Set 1 | ylivieska
# Processing Record 200 of Set 1 | bartica
# Processing Record 201 of Set 1 | hasaki
# Processing Record 202 of Set 1 | bathsheba
# Processing Record 203 of Set 1 | padang
# Processing Record 204 of Set 1 | ust-nera
# Processing Record 205 of Set 1 | oranjemund
# Processing Record 206 of Set 1 | toliary
# Insufficient data. Skipping..
# Processing Record 206 of Set 1 | georgetown
# Processing Record 207 of Set 1 | los llanos de aridane
# Processing Record 208 of Set 1 | liberty
# Processing Record 209 of Set 1 | manaus
# Processing Record 210 of Set 1 | springbok
# Processing Record 211 of Set 1 | waipawa
# Processing Record 212 of Set 1 | wagar
# Processing Record 213 of Set 1 | mandalgovi
# Processing Record 214 of Set 1 | broome
# Processing Record 215 of Set 1 | gushikawa
# Processing Record 216 of Set 1 | afua
# Processing Record 217 of Set 1 | airai
# Processing Record 218 of Set 1 | nanortalik
# Processing Record 219 of Set 1 | vuktyl
# Processing Record 220 of Set 1 | kikwit
# Processing Record 221 of Set 1 | muborak
# Processing Record 222 of Set 1 | clyde river
# Processing Record 223 of Set 1 | finnsnes
# Processing Record 224 of Set 1 | chikoy
# Insufficient data. Skipping..
# Processing Record 224 of Set 1 | karangasem
# Processing Record 225 of Set 1 | hami
# Processing Record 226 of Set 1 | gayny
# Processing Record 227 of Set 1 | kumano
# Processing Record 228 of Set 1 | pisco
# Processing Record 229 of Set 1 | bethel
# Processing Record 230 of Set 1 | turukhansk
# Processing Record 231 of Set 1 | geraldton
# Processing Record 232 of Set 1 | thompson
# Processing Record 233 of Set 1 | lewiston
# Processing Record 234 of Set 1 | sao jose da coroa grande
# Processing Record 235 of Set 1 | samarai
# Processing Record 236 of Set 1 | waddan
# Processing Record 237 of Set 1 | dakar
# Processing Record 238 of Set 1 | salinopolis
# Processing Record 239 of Set 1 | san ramon
# Processing Record 240 of Set 1 | abu dhabi
# Processing Record 241 of Set 1 | jian
# Processing Record 242 of Set 1 | cherskiy
# Processing Record 243 of Set 1 | batagay
# Processing Record 244 of Set 1 | karratha
# Processing Record 245 of Set 1 | bowen
# Processing Record 246 of Set 1 | puerto baquerizo moreno
# Processing Record 247 of Set 1 | torbay
# Processing Record 248 of Set 1 | sigli
# Processing Record 249 of Set 1 | nizhneyansk
# Insufficient data. Skipping..
# Processing Record 249 of Set 1 | sekudai
# Processing Record 250 of Set 1 | kiunga
# Processing Record 251 of Set 1 | baruun-urt
# Processing Record 252 of Set 1 | umm lajj
# Processing Record 253 of Set 1 | warqla
# Insufficient data. Skipping..
# Processing Record 253 of Set 1 | masjed-e soleyman
# Insufficient data. Skipping..
# Processing Record 253 of Set 1 | grand centre
# Insufficient data. Skipping..
# Processing Record 253 of Set 1 | svelgen
# Processing Record 254 of Set 1 | visby
# Processing Record 255 of Set 1 | mangrol
# Processing Record 256 of Set 1 | roma
# Processing Record 257 of Set 1 | ewa beach
# Processing Record 258 of Set 1 | udachnyy
# Processing Record 259 of Set 1 | zhoucun
# Processing Record 260 of Set 1 | haukipudas
# Processing Record 261 of Set 1 | bay roberts
# Processing Record 262 of Set 1 | sandpoint
# Processing Record 263 of Set 1 | port augusta
# Processing Record 264 of Set 1 | gerash
# Processing Record 265 of Set 1 | souillac
# Processing Record 266 of Set 1 | takaka
# Processing Record 267 of Set 1 | provideniya
# Processing Record 268 of Set 1 | calvillo
# Processing Record 269 of Set 1 | kalinovskaya
# Processing Record 270 of Set 1 | hovd
# Processing Record 271 of Set 1 | moultrie
# Processing Record 272 of Set 1 | tamuin
# Processing Record 273 of Set 1 | dalbandin
# Processing Record 274 of Set 1 | srednekolymsk
# Processing Record 275 of Set 1 | samusu
# Insufficient data. Skipping..
# Processing Record 275 of Set 1 | talcahuano
# Processing Record 276 of Set 1 | trelew
# Processing Record 277 of Set 1 | luderitz
# Processing Record 278 of Set 1 | saskylakh
# Processing Record 279 of Set 1 | lorengau
# Processing Record 280 of Set 1 | muros
# Processing Record 281 of Set 1 | portobelo
# Processing Record 282 of Set 1 | yumen
# Processing Record 283 of Set 1 | constitucion
# Processing Record 284 of Set 1 | mbini
# Processing Record 285 of Set 1 | san cristobal
# Processing Record 286 of Set 1 | tynda
# Processing Record 287 of Set 1 | port-gentil
# Processing Record 288 of Set 1 | houma
# Processing Record 289 of Set 1 | hailar
# Processing Record 290 of Set 1 | goderich
# Processing Record 291 of Set 1 | lasa
# Processing Record 292 of Set 1 | tigil
# Processing Record 293 of Set 1 | kuala terengganu
# Processing Record 294 of Set 1 | faranah
# Processing Record 295 of Set 1 | kurilsk
# Processing Record 296 of Set 1 | sitka
# Processing Record 297 of Set 1 | san quintin
# Processing Record 298 of Set 1 | barabai
# Processing Record 299 of Set 1 | pachino
# Processing Record 300 of Set 1 | pacific grove
# Processing Record 301 of Set 1 | qaanaaq
# Processing Record 302 of Set 1 | gimli
# Processing Record 303 of Set 1 | campo verde
# Processing Record 304 of Set 1 | naze
# Processing Record 305 of Set 1 | vengurla
# Processing Record 306 of Set 1 | rungata
# Insufficient data. Skipping..
# Processing Record 306 of Set 1 | adrar
# Processing Record 307 of Set 1 | tessalit
# Processing Record 308 of Set 1 | biasca
# Processing Record 309 of Set 1 | aswan
# Processing Record 310 of Set 1 | kahuta
# Processing Record 311 of Set 1 | sandviken
# Processing Record 312 of Set 1 | warren
# Processing Record 313 of Set 1 | buchanan
# Processing Record 314 of Set 1 | iqaluit
# Processing Record 315 of Set 1 | bereda
# Processing Record 316 of Set 1 | englewood
# Processing Record 317 of Set 1 | paamiut
# Processing Record 318 of Set 1 | gamba
# Processing Record 319 of Set 1 | bud
# Processing Record 320 of Set 1 | lumphat
# Processing Record 321 of Set 1 | chicama
# Processing Record 322 of Set 1 | ternate
# Processing Record 323 of Set 1 | faya
# Processing Record 324 of Set 1 | jalu
# Processing Record 325 of Set 1 | qasigiannguit
# Processing Record 326 of Set 1 | harwich
# Processing Record 327 of Set 1 | meridian
# Processing Record 328 of Set 1 | concordia
# Processing Record 329 of Set 1 | podosinovets
# Processing Record 330 of Set 1 | te anau
# Processing Record 331 of Set 1 | syke
# Processing Record 332 of Set 1 | tevaitoa
# Processing Record 333 of Set 1 | lamu
# Processing Record 334 of Set 1 | yatou
# Processing Record 335 of Set 1 | merritt
# Processing Record 336 of Set 1 | talara
# Processing Record 337 of Set 1 | marsala
# Processing Record 338 of Set 1 | malartic
# Processing Record 339 of Set 1 | la ronge
# Processing Record 340 of Set 1 | sangar
# Processing Record 341 of Set 1 | manaure
# Processing Record 342 of Set 1 | praia
# Processing Record 343 of Set 1 | fairbanks
# Processing Record 344 of Set 1 | waitara
# Processing Record 345 of Set 1 | lephepe
# Insufficient data. Skipping..
# Processing Record 345 of Set 1 | grindavik
# Processing Record 346 of Set 1 | portland
# Processing Record 347 of Set 1 | langham
# Processing Record 348 of Set 1 | yomitan
# Insufficient data. Skipping..
# Processing Record 348 of Set 1 | tahe
# Processing Record 349 of Set 1 | lufilufi
# Processing Record 350 of Set 1 | iroquois falls
# Processing Record 351 of Set 1 | basco
# Processing Record 352 of Set 1 | sevlievo
# Processing Record 353 of Set 1 | ileza
# Processing Record 354 of Set 1 | owando
# Processing Record 355 of Set 1 | dzhusaly
# Insufficient data. Skipping..
# Processing Record 355 of Set 1 | preobrazheniye
# Processing Record 356 of Set 1 | east london
# Processing Record 357 of Set 1 | meyungs
# Insufficient data. Skipping..
# Processing Record 357 of Set 1 | benito juarez
# Processing Record 358 of Set 1 | jiayuguan
# Processing Record 359 of Set 1 | zwedru
# Processing Record 360 of Set 1 | presidente epitacio
# Processing Record 361 of Set 1 | hofn
# Processing Record 362 of Set 1 | nantucket
# Processing Record 363 of Set 1 | dunedin
# Processing Record 364 of Set 1 | yulara
# Processing Record 365 of Set 1 | quatre cocos
# Processing Record 366 of Set 1 | pitimbu
# Processing Record 367 of Set 1 | vila franca do campo
# Processing Record 368 of Set 1 | salalah
# Processing Record 369 of Set 1 | shelburne
# Processing Record 370 of Set 1 | icod de los vinos
# Processing Record 371 of Set 1 | taurianova
# Processing Record 372 of Set 1 | shimoda
# Processing Record 373 of Set 1 | mitchell
# Processing Record 374 of Set 1 | kenai
# Processing Record 375 of Set 1 | palauig
# Processing Record 376 of Set 1 | bhim tal
# Processing Record 377 of Set 1 | sola
# Processing Record 378 of Set 1 | lolua
# Insufficient data. Skipping..
# Processing Record 378 of Set 1 | abu zabad
# Processing Record 379 of Set 1 | jieshi
# Processing Record 380 of Set 1 | muravlenko
# Processing Record 381 of Set 1 | sambava
# Processing Record 382 of Set 1 | ojinaga
# Processing Record 383 of Set 1 | camacha
# Processing Record 384 of Set 1 | khvorostyanka
# Processing Record 385 of Set 1 | athabasca
# Processing Record 386 of Set 1 | bloomington
# Processing Record 387 of Set 1 | usevya
# Insufficient data. Skipping..
# Processing Record 387 of Set 1 | birin
# Processing Record 388 of Set 1 | myitkyina
# Processing Record 389 of Set 1 | joshimath
# Processing Record 390 of Set 1 | kota belud
# Processing Record 391 of Set 1 | gat
# Processing Record 392 of Set 1 | khandyga
# Processing Record 393 of Set 1 | marawi
# Processing Record 394 of Set 1 | henties bay
# Processing Record 395 of Set 1 | saint-joseph
# Processing Record 396 of Set 1 | aykhal
# Processing Record 397 of Set 1 | navirai
# Processing Record 398 of Set 1 | vila
# Processing Record 399 of Set 1 | newport
# Processing Record 400 of Set 1 | antofagasta
# Processing Record 401 of Set 1 | tutoia
# Processing Record 402 of Set 1 | olafsvik
# Insufficient data. Skipping..
# Processing Record 402 of Set 1 | beringovskiy
# Processing Record 403 of Set 1 | barao de melgaco
# Processing Record 404 of Set 1 | launceston
# Processing Record 405 of Set 1 | yerbogachen
# Processing Record 406 of Set 1 | eyrarbakki
# Processing Record 407 of Set 1 | kamaishi
# Processing Record 408 of Set 1 | nchelenge
# Processing Record 409 of Set 1 | vanimo
# Processing Record 410 of Set 1 | puerto cabezas
# Processing Record 411 of Set 1 | bobbili
# Processing Record 412 of Set 1 | weligama
# Processing Record 413 of Set 1 | innisfail
# Processing Record 414 of Set 1 | manggar
# Processing Record 415 of Set 1 | verkhnyaya toyma
# Processing Record 416 of Set 1 | kinshasa
# Processing Record 417 of Set 1 | aleksandrovsk-sakhalinskiy
# Processing Record 418 of Set 1 | williston
# Processing Record 419 of Set 1 | opuwo
# Processing Record 420 of Set 1 | aguimes
# Processing Record 421 of Set 1 | halalo
# Insufficient data. Skipping..
# Processing Record 421 of Set 1 | brae
# Processing Record 422 of Set 1 | terra santa
# Processing Record 423 of Set 1 | almansa
# Processing Record 424 of Set 1 | saleaula
# Insufficient data. Skipping..
# Processing Record 424 of Set 1 | kifri
# Processing Record 425 of Set 1 | touros
# Processing Record 426 of Set 1 | berlevag
# Processing Record 427 of Set 1 | qaqortoq
# Processing Record 428 of Set 1 | calamar
# Processing Record 429 of Set 1 | arinos
# Processing Record 430 of Set 1 | ati
# Processing Record 431 of Set 1 | meulaboh
# Processing Record 432 of Set 1 | acari
# Processing Record 433 of Set 1 | ishnya
# Processing Record 434 of Set 1 | khani
# Processing Record 435 of Set 1 | frisco
# Processing Record 436 of Set 1 | sinjai
# Processing Record 437 of Set 1 | chibombo
# Processing Record 438 of Set 1 | iquique
# Processing Record 439 of Set 1 | dwarka
# Processing Record 440 of Set 1 | garmsar
# Processing Record 441 of Set 1 | marhaura
# Processing Record 442 of Set 1 | kankon
# Processing Record 443 of Set 1 | swellendam
# Processing Record 444 of Set 1 | durango
# Processing Record 445 of Set 1 | warrington
# Processing Record 446 of Set 1 | rundu
# Processing Record 447 of Set 1 | beyneu
# Processing Record 448 of Set 1 | kongwa
# Processing Record 449 of Set 1 | panjab
# Processing Record 450 of Set 1 | lidkoping
# Processing Record 451 of Set 1 | tezu
# Processing Record 452 of Set 1 | port keats
# Processing Record 453 of Set 1 | george town
# Processing Record 454 of Set 1 | khorixas
# Processing Record 455 of Set 1 | nizhniy tsasuchey
# Processing Record 456 of Set 1 | tautira
# Processing Record 457 of Set 1 | powell river
# Processing Record 458 of Set 1 | cabinda
# Processing Record 459 of Set 1 | mingaora
# Processing Record 460 of Set 1 | fukuma
# Processing Record 461 of Set 1 | san vicente
# Processing Record 462 of Set 1 | cap malheureux
# Processing Record 463 of Set 1 | katsuura
# Processing Record 464 of Set 1 | tiznit
# Processing Record 465 of Set 1 | north bend
# Processing Record 466 of Set 1 | lusambo
# Processing Record 467 of Set 1 | inhambane
# Processing Record 468 of Set 1 | jinji
# Processing Record 469 of Set 1 | maragogi
# Processing Record 470 of Set 1 | ondjiva
# Processing Record 471 of Set 1 | nalut
# Processing Record 472 of Set 1 | port-de-paix
# Insufficient data. Skipping..
# Processing Record 472 of Set 1 | agadez
# Processing Record 473 of Set 1 | opobo
# Insufficient data. Skipping..
# Processing Record 473 of Set 1 | belmonte
# Processing Record 474 of Set 1 | bua yai
# Processing Record 475 of Set 1 | leshukonskoye
# Processing Record 476 of Set 1 | waw
# Insufficient data. Skipping..
# Processing Record 476 of Set 1 | rancho palos verdes
# Processing Record 477 of Set 1 | luba
# Processing Record 478 of Set 1 | anito
# Processing Record 479 of Set 1 | byron bay
# Processing Record 480 of Set 1 | little current
# Processing Record 481 of Set 1 | freeport
# Processing Record 482 of Set 1 | santa lucia
# Processing Record 483 of Set 1 | shache
# Processing Record 484 of Set 1 | labutta
# Insufficient data. Skipping..
# Processing Record 484 of Set 1 | mehamn
# Processing Record 485 of Set 1 | kolodeznyy
# Processing Record 486 of Set 1 | aksarka
# Processing Record 487 of Set 1 | benghazi
# Processing Record 488 of Set 1 | bozeman
# Processing Record 489 of Set 1 | grand river south east
# Insufficient data. Skipping..
# Processing Record 489 of Set 1 | bairiki
# Insufficient data. Skipping..
# Processing Record 489 of Set 1 | biak
# Processing Record 490 of Set 1 | porto novo
# Processing Record 491 of Set 1 | kokkola
# Processing Record 492 of Set 1 | piopio
# Processing Record 493 of Set 1 | auki
# Processing Record 494 of Set 1 | tomatlan
# Processing Record 495 of Set 1 | abha
# Processing Record 496 of Set 1 | rawson
# Processing Record 497 of Set 1 | antalaha
# Processing Record 498 of Set 1 | port hardy
# Processing Record 499 of Set 1 | boueni
# Processing Record 500 of Set 1 | puerto carreno
# Processing Record 501 of Set 1 | dolzhanskaya
# Processing Record 502 of Set 1 | teknaf
# Processing Record 503 of Set 1 | maldonado
# Processing Record 504 of Set 1 | mount gambier
# Processing Record 505 of Set 1 | zavodouspenskoye
# Processing Record 506 of Set 1 | blonduos
# Insufficient data. Skipping..
# Processing Record 506 of Set 1 | kidodi
# Processing Record 507 of Set 1 | dryden
# Processing Record 508 of Set 1 | rio gallegos
# Processing Record 509 of Set 1 | axim
# Processing Record 510 of Set 1 | salta
# Processing Record 511 of Set 1 | yanam
# Processing Record 512 of Set 1 | grand gaube
# Processing Record 513 of Set 1 | itaituba
# Processing Record 514 of Set 1 | progreso
# Processing Record 515 of Set 1 | ambon
# Processing Record 516 of Set 1 | susanville
# Processing Record 517 of Set 1 | nelson bay
# Processing Record 518 of Set 1 | adre
# Processing Record 519 of Set 1 | caucaia
# Processing Record 520 of Set 1 | solsvik
# Insufficient data. Skipping..
# Processing Record 520 of Set 1 | nyrob
# Processing Record 521 of Set 1 | zhuhai
# Processing Record 522 of Set 1 | ust-bolsheretsk
# Insufficient data. Skipping..
# Processing Record 522 of Set 1 | sistranda
# Processing Record 523 of Set 1 | shambu
# Processing Record 524 of Set 1 | zitlaltepec
# Processing Record 525 of Set 1 | marilia
# Processing Record 526 of Set 1 | koilas
# Processing Record 527 of Set 1 | barcelos
# Processing Record 528 of Set 1 | altay
# Processing Record 529 of Set 1 | moranbah
# Processing Record 530 of Set 1 | churapcha
# Processing Record 531 of Set 1 | pecos
# Processing Record 532 of Set 1 | iranshahr
# Processing Record 533 of Set 1 | mecca
# Processing Record 534 of Set 1 | vaitupu
# Insufficient data. Skipping..
# Processing Record 534 of Set 1 | high level
# Processing Record 535 of Set 1 | tilichiki
# Processing Record 536 of Set 1 | copiapo
# Processing Record 537 of Set 1 | dubova
# Processing Record 538 of Set 1 | oranjestad
# Processing Record 539 of Set 1 | hay river
# Processing Record 540 of Set 1 | santa cruz
# Processing Record 541 of Set 1 | tura
# Processing Record 542 of Set 1 | kavos
# Processing Record 543 of Set 1 | atka
# Insufficient data. Skipping..
# Processing Record 543 of Set 1 | batamshinskiy
# Processing Record 544 of Set 1 | buin
#
# --------------------------------------------------------------------------------
#                                 Data Retrieval Complete
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#weather_df.to_csv(output_data_file)
weather_df.head(20)
# Out:
#                   City Name Country  Latitude  Longitude        Date  \
# 0                   wuchang      CN     44.93      44.93  2019-01-07
# 1               pangnirtung      CA     66.15      66.15  2019-01-07
# 2                  were ilu      ET     10.60      10.60  2019-01-07
# 3                bredasdorp      ZA    -34.53     -34.53  2019-01-07
# 4                  khatanga      RU     71.98      71.98  2019-01-07
# 5            guerrero negro      MX     27.97      27.97  2019-01-07
# 6                     vaini      IN     15.34      15.34  2019-01-07
# 7            port elizabeth      US     39.31      39.31  2019-01-06
# 8                  saldanha      PT     41.42      41.42  2019-01-07
# 9                hervey bay      AU    -25.30     -25.30  2019-01-07
# 10                  rikitea      PF    -23.12     -23.12  2019-01-07
# 11              port alfred      ZA    -33.59     -33.59  2019-01-07
# 12                hithadhoo      MV     -0.60      -0.60  2019-01-07
# 13  marechal candido rondon      BR    -24.56     -24.56  2019-01-07
# 14                     hilo      US     19.71      19.71  2019-01-06
# 15              yellowknife      CA     62.45      62.45  2019-01-07
# 16             punta arenas      CL    -53.16     -53.16  2019-01-07
# 17                   albany      US     42.65      42.65  2019-01-07
# 18          bambous virieux      MU    -20.34     -20.34  2019-01-07
# 19                 seymchan      RU     62.93      62.93  2019-01-07
#
#     Temperature  Humidity  Wind Speed  Clouds
# 0         10.77      52.0        8.21    56.0
# 1        -13.45      82.0        9.89    44.0
# 2         56.17      25.0        1.16     8.0
# 3         69.80      68.0        5.82    75.0
# 4        -37.75       0.0        3.62    20.0
# 5         49.47     100.0        4.63    12.0
# 6         78.80      31.0       11.41     0.0
# 7         37.04      60.0        6.93     1.0
# 8         16.66      73.0        2.84     0.0
# 9         80.60      57.0       17.22    40.0
# 10        80.02      95.0       13.02   100.0
# 11        70.80      83.0        9.66     8.0
# 12        79.21     100.0        5.64    68.0
# 13        76.11      87.0       13.80    76.0
# 14        69.98      87.0        3.36    40.0
# 15       -16.61      75.0       13.87     5.0
# 16        39.20     100.0        8.05    75.0
# 17        21.02      51.0       16.11     1.0
# 18        84.20      83.0       18.34    75.0
# 19       -18.71      77.0        5.64    56.0

# %%
weather_df.count()
# Out:
# City Name      544
# Country        544
# Latitude       544
# Longitude      544
# Date           544
# Temperature    544
# Humidity       544
# Wind Speed     544
# Clouds         544
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
lat_v_temp = ax.scatter(
    weather_df["Latitude"],
    weather_df["Temperature"],
    alpha=0.7,
    edgecolor="black",   
)

ax.set_title("City Latitude v. Max Temperature (2018)")
ax.set_ylabel("Max Temperature(F)")
ax.set_xlabel("Latitude")
ax.grid(b=None)

plt.savefig("Lat ~ Temp")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
lat_v_humid = ax.scatter(
    weather_df["Latitude"],
    weather_df["Humidity"],
    alpha=0.7,
    edgecolor="black",   
)

ax.set_title("City Latitude v. Humidity (2018)")
ax.set_ylabel("Humidity (%)")
ax.set_xlabel("Latitude")
ax.grid(b=None)

plt.savefig("Lat ~ Humid")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
lat_v_cloud = ax.scatter(
    weather_df["Latitude"],
    weather_df["Clouds"],
    alpha=0.7,
    edgecolor="black",   
)

ax.set_title("City Latitude v. Cloudiness (2018)")
ax.set_ylabel("Cloudiness (%)")
ax.set_xlabel("Latitude")
ax.grid(b=None)

plt.savefig("Lat ~ Cloud")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
lat_v_cloud = ax.scatter(
    weather_df["Latitude"],
    weather_df["Wind Speed"],
    alpha=0.7,
    edgecolor="black",   
)

ax.set_title("City Latitude v. Wind Speed (2018)")
ax.set_ylabel("Wind Speed (mph)")
ax.set_xlabel("Latitude")
ax.grid(b=None)

plt.savefig("Lat ~ Wind")
